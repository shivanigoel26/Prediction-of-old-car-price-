# %% [markdown]
# ## importing packages

# %%
import pandas as pd
import numpy as np
import pandas_profiling as pp
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from tkinter import *
from functools import partial
import datetime
#Reading CSV file
car = pd.read_csv('car.csv',index_col=0)

# data understanding
car.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price
# 0        NaN   1.75
# 1        NaN  12.50
# ...

# %%
#changing name of columns
car.columns = ['Name','Location','Year','Kilometers_Driven','Fuel_Type','Transmission','Owner_Type','Mileage',
                    'Engine_CC','Power_bhp','Seats','New_Price','Price_Lakh']

# %% [markdown]
# # Data analysis

# %%
# top 5 rows data
car.head(5)
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage Engine_CC  Power_bhp  Seats  \
# 0       CNG       Manual      First  26.6 km/kg    998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl   1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl   1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl   1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl   1968 CC  140.8 bhp    5.0
#
#    New_Price  Price_Lakh
# 0        NaN        1.75
# ...

# %%
#bottom 5 rows data
car.tail(5)
# Out:
#                           Name   Location  Year  Kilometers_Driven Fuel_Type  \
# 6014          Maruti Swift VDI      Delhi  2014              27365    Diesel
# 6015  Hyundai Xcent 1.1 CRDi S     Jaipur  2015             100000    Diesel
# 6016     Mahindra Xylo D4 BSIV     Jaipur  2012              55000    Diesel
# 6017        Maruti Wagon R VXI    Kolkata  2013              46000    Petrol
# 6018     Chevrolet Beat Diesel  Hyderabad  2011              47000    Diesel
#
#      Transmission Owner_Type     Mileage Engine_CC Power_bhp  Seats  \
# 6014       Manual      First   28.4 kmpl   1248 CC    74 bhp    5.0
# 6015       Manual      First   24.4 kmpl   1120 CC    71 bhp    5.0
# 6016       Manual     Second   14.0 kmpl   2498 CC   112 bhp    8.0
# 6017       Manual      First   18.9 kmpl    998 CC  67.1 bhp    5.0
# 6018       Manual      First  25.44 kmpl    936 CC  57.6 bhp    5.0
#
#       New_Price  Price_Lakh
# 6014  7.88 Lakh        4.75
# 6015        NaN        4.00
# ...

# %%
# shape of our dataset
car.shape
# Out:
# (6019, 13)

# %% [markdown]
# ##### There are 6019 rows and 13 columns

# %%
# information of data set
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6019 entries, 0 to 6018
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               6019 non-null   object
#  1   Location           6019 non-null   object
#  2   Year               6019 non-null   int64
#  3   Kilometers_Driven  6019 non-null   int64
#  4   Fuel_Type          6019 non-null   object
#  5   Transmission       6019 non-null   object
#  6   Owner_Type         6019 non-null   object
#  7   Mileage            6017 non-null   object
#  8   Engine_CC          5983 non-null   object
#  9   Power_bhp          5983 non-null   object
#  10  Seats              5977 non-null   float64
#  11  New_Price          824 non-null    object
#  12  Price_Lakh         6019 non-null   float64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 658.3+ KB

# %%
#size of dataset
car.size
# Out:
# 78247

# %%
#check datatype of each attributes
car.dtypes
# Out:
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage               object
# Engine_CC             object
# Power_bhp             object
# Seats                float64
# New_Price             object
# Price_Lakh           float64
# dtype: object

# %%
# total number of each data types in data set  
car.get_dtype_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-903476be9a0d> in <module>
#       1 # total number of each data types in data set
# ----> 2 car.get_dtype_counts()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'get_dtype_counts'

# %%
# number of entities of each columns
car.count()
# Out:
# Name                 6019
# Location             6019
# Year                 6019
# Kilometers_Driven    6019
# Fuel_Type            6019
# Transmission         6019
# Owner_Type           6019
# Mileage              6017
# Engine_CC            5983
# Power_bhp            5983
# Seats                5977
# New_Price             824
# Price_Lakh           6019
# dtype: int64

# %% [markdown]
# ## Profile report

# %%
# profile report of data set
pp.ProfileReport(car)

# %%
# check the NaN values
car.isnull()
# Out:
#        Name  Location   Year  Kilometers_Driven  Fuel_Type  Transmission  \
# 0     False     False  False              False      False         False
# 1     False     False  False              False      False         False
# 2     False     False  False              False      False         False
# 3     False     False  False              False      False         False
# 4     False     False  False              False      False         False
# ...     ...       ...    ...                ...        ...           ...
# 6014  False     False  False              False      False         False
# 6015  False     False  False              False      False         False
# 6016  False     False  False              False      False         False
# 6017  False     False  False              False      False         False
# 6018  False     False  False              False      False         False
#
#       Owner_Type  Mileage  Engine_CC  Power_bhp  Seats  New_Price  Price_Lakh
# ...

# %%
# sum of null values of each column
car.isnull().sum()
# Out:
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine_CC              36
# Power_bhp              36
# Seats                  42
# New_Price            5195
# Price_Lakh              0
# dtype: int64

# %% [markdown]
# ### Dropping duplicate values

# %%
#dropping duplicate values
car.drop_duplicates()
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
# ...

# %% [markdown]
# ### Transforming data using function

# %% [markdown]
# #### New Price

# %%
car.drop('New_Price',axis=1,inplace=True)

# %% [markdown]
# #### Engine

# %%
# removing unit "CC" from Engine column to analyse data
def clean_CC(y):
    if isinstance(y, str):
        return(y.replace('CC', '').replace(',', ''))
    return(y)
# applying clean_CC() to values of engine column
car['Engine_CC'] = car['Engine_CC'].apply(clean_CC).astype('float')

# %% [markdown]
# #### Power

# %%
# removing unit "bnp" from Power column to analyse data
def clean_bhp(z):
    if isinstance(z, str):
        return(z.replace('bhp', '').replace(',', ''))
    return(z)
# applying clean_bhp() to values of engine column
car['Power_bhp'] = car['Power_bhp'].apply(clean_bhp)

# %% [markdown]
# #### Mileage

# %%
# Transforming data of mileage fuction
convert_dict1 = {'Mileage': str } 

car = car.astype(convert_dict1)

# function to chnage km/kg into kmpl
def kml(k):
    l = k.split(' ')
    if "km/kg" in k:
        return (str(float(l[0])) +" "+ "kmpl")
    if "kmpl" in k:
        return (str(float(l[0])) +" "+ "kmpl")
    else:
        return (str(float(l[0])))

# Applying Mileage column values in kml()
car['Mileage'] = car['Mileage'].apply(kml)

# removing units from  Mileage column to analyse data
def clean_unit(k1):
    if isinstance(k1, str):
        return(k1.replace('kmpl', '').replace(',', ''))
    return(k1)

# updating Mileage column values in data set
car['Mileage'] = car['Mileage'].apply(clean_unit)

#checking tha datatypes
car.dtypes
# Out:
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage               object
# Engine_CC            float64
# Power_bhp             object
# Seats                float64
# Price_Lakh           float64
# dtype: object

# %% [markdown]
# ### Name

# %%
new_column = car["Name"].str.split(" ", expand = True)
car["Manufacturer"] = new_column[0]
plot = sns.countplot(x = 'Manufacturer', data = car)
plt.xticks(rotation = 90)
for p in plot.patches:
    plot.annotate(p.get_height(), 
                        (p.get_x() + p.get_width() / 2.0, 
                         p.get_height()), 
                        ha = 'center', 
                        va = 'center', 
                        xytext = (0, 5),
                        textcoords = 'offset points')

plt.title("Count of cars based on manufacturers")
plt.xlabel("Manufacturer")
plt.ylabel("Count of cars")
# Out:
# Text(0, 0.5, 'Count of cars')

# %% [markdown]
# ###### Dropping name column

# %%
#I will drop the name ciolumn as it is replaced by manufacturer

car.drop('Name',axis=1,inplace=True)

# %% [markdown]
# #### Location

# %% [markdown]
# ###### Dropping location column as it has no significant use in predicting car price

# %%
car.drop("Location", axis = 1, inplace = True)

# %% [markdown]
# #### Year

# %%
current_time = datetime.datetime.now()
car['Year'] = car['Year'].apply(lambda x : current_time.year - x)

# %% [markdown]
# #### Fuel_Type , Transmission_Type and Owner_Type

# %% [markdown]
# ###### All these columns are categorical columns which should be converted to dummy variables before being used.

# %%
car.head()
# Out:
#    Year  Kilometers_Driven Fuel_Type Transmission Owner_Type Mileage  \
# 0    10              72000       CNG       Manual      First   26.6
# 1     5              41000    Diesel       Manual      First  19.67
# 2     9              46000    Petrol       Manual      First   18.2
# 3     8              87000    Diesel       Manual      First  20.77
# 4     7              40670    Diesel    Automatic     Second   15.2
#
#    Engine_CC Power_bhp  Seats  Price_Lakh Manufacturer
# 0      998.0    58.16     5.0        1.75       Maruti
# 1     1582.0    126.2     5.0       12.50      Hyundai
# 2     1199.0     88.7     5.0        4.50        Honda
# 3     1248.0    88.76     7.0        6.00       Maruti
# 4     1968.0    140.8     5.0       17.74         Audi

# %% [markdown]
# ### Type conversion

# %%
#type conversion of Power(in bhp) from object type to float data type
car['Power_bhp'] = pd.to_numeric(car['Power_bhp'],errors='coerce')

car.Power_bhp.isna().sum()

# type conversion of Mileage from object type to float
car['Mileage'] = pd.to_numeric(car['Mileage'],errors='coerce')

car.Mileage.isna().sum()
# Out:
# 2

# %%
# final data types of attributes of data set
car.dtypes
# Out:
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage              float64
# Engine_CC            float64
# Power_bhp            float64
# Seats                float64
# Price_Lakh           float64
# Manufacturer          object
# dtype: object

# %%
# Check the NaN values of attributes
car.isna().sum()
# Out:
# Year                   0
# Kilometers_Driven      0
# Fuel_Type              0
# Transmission           0
# Owner_Type             0
# Mileage                2
# Engine_CC             36
# Power_bhp            143
# Seats                 42
# Price_Lakh             0
# Manufacturer           0
# dtype: int64

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# #### Mileage

# %%
car.Mileage.replace(0,np.nan)
car.Mileage.fillna(car.Mileage.mean(),inplace=True)
car.Mileage.isna().sum()
# Out:
# 0

# %% [markdown]
# #### Engine

# %%
car.Engine_CC.replace(0,np.nan)
car.Engine_CC.fillna(car.Engine_CC.mean(),inplace=True)
car.Engine_CC.isna().sum()
# Out:
# 0

# %% [markdown]
# #### Power

# %%
car.Power_bhp.replace(0,np.nan)
car.Power_bhp.fillna(car.Power_bhp.mean(),inplace=True)
car.Power_bhp.isna().sum()
# Out:
# 0

# %% [markdown]
# #### Seats

# %%
car.Seats.replace(0,np.nan)
car.Seats.fillna(car.Seats.mean(),inplace=True)
car.Seats.isna().sum()
# Out:
# 0

# %% [markdown]
# ## Cleaned Dataset

# %%
#Storing the cleaned dataset in car_data file
car.to_csv('cardata.csv')
car.head()
# Out:
#    Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  \
# 0    10              72000       CNG       Manual      First    26.60
# 1     5              41000    Diesel       Manual      First    19.67
# 2     9              46000    Petrol       Manual      First    18.20
# 3     8              87000    Diesel       Manual      First    20.77
# 4     7              40670    Diesel    Automatic     Second    15.20
#
#    Engine_CC  Power_bhp  Seats  Price_Lakh Manufacturer
# 0      998.0      58.16    5.0        1.75       Maruti
# 1     1582.0     126.20    5.0       12.50      Hyundai
# 2     1199.0      88.70    5.0        4.50        Honda
# 3     1248.0      88.76    7.0        6.00       Maruti
# 4     1968.0     140.80    5.0       17.74         Audi

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# #### Year

# %%
car['Year'].value_counts().plot(kind='bar')
car['Year'].value_counts()
plt.xlabel('Year')
plt.ylabel('frequency')
plt.title('Age of Car')
# Out:
# Text(0.5, 1.0, 'Age of Car')

# %% [markdown]
# #### Fuel type

# %%
sns.countplot(car['Fuel_Type'])
plt.title("Fuel Type")
plt.xlabel('fuel type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### Transmission

# %%
sns.countplot(car['Transmission'])
plt.title("Transmission type")
plt.xlabel('Transmission')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### Owner type

# %%
sns.countplot(car['Owner_Type'])
plt.title("Owner Type")
plt.xlabel('owner type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### Seats

# %%
sns.countplot(car['Seats'])
plt.title("Number of seats in car")
plt.xlabel('Seats')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### Price_Lakh

# %%
plt.hist(car['Price_Lakh'])
# Out:
# (array([5.098e+03, 6.190e+02, 2.000e+02, 6.400e+01, 2.900e+01, 5.000e+00,
#         2.000e+00, 1.000e+00, 0.000e+00, 1.000e+00]),
#  array([  0.44 ,  16.396,  32.352,  48.308,  64.264,  80.22 ,  96.176,
#         112.132, 128.088, 144.044, 160.   ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### Distribution of car prices

# %%
sns.set_style('darkgrid')
sns.distplot(car['Price_Lakh'])
plt.ylabel("frequency")
plt.title("Density plot of car prices")
# Out:
# Text(0.5, 1.0, 'Density plot of car prices')

# %% [markdown]
# ### Distribution of car by condition

# %%
car['Owner_Type'].value_counts().plot(kind='bar')
car['Owner_Type'].value_counts()
plt.ylabel("frequency")
plt.title("Number of sold cars by condition")
# Out:
# Text(0.5, 1.0, 'Number of sold cars by condition')

# %% [markdown]
# ### Fuel Type against Transmission

# %%
survive = sns.countplot(x = 'Fuel_Type', hue = 'Transmission', palette = 'Set3', data = car)
survive.set(title = 'Fuel Type against Transmission', xlabel = 'Fuel type',ylabel="")
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ### Histogram

# %%
car.hist(figsize=(12,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001F5A5A84C18>,
# ...
#       dtype=object)

# %% [markdown]
# ### Strip plot

# %%
sns.stripplot(x=car['Engine_CC'])

# %%
sns.stripplot(x=car['Power_bhp'])

# %%
sns.stripplot(x=car['Price_Lakh'],color='purple')

# %% [markdown]
# ### Box plot

# %%
sns.boxplot(x=car['Seats'])

# %%
sns.boxplot(x='Fuel_Type',y='Price_Lakh',data=car)

# %% [markdown]
# ### Univariate Analysis

# %%
#univariate analysis
for i in car.describe().columns:
    sns.distplot(car[i])
    plt.show()
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Correlation Matrix

# %%
import seaborn as sns
plt.figure(figsize=(12,6))
sns.heatmap(car.corr(),annot=True,cmap='YlGnBu')

# %% [markdown]
# ### Bivariate Analysis

# %%
#bivariate analysis
for i, col in enumerate (car.columns):
    plt.figure(i)
    sns.scatterplot(x=car[col],y=car['Price_Lakh'])

# %%
#bivariate analysis
sns.pairplot(car)

# %% [markdown]
# ### Identifying and removing outliers

# %%
#identify ouliers
for i in car.describe().columns:
    sns.boxplot(car[i])
    plt.show()

# %% [markdown]
# ### Detecting outliers using IQR score

# %%
Q1 = car.quantile(0.25)
Q3 = car.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Year                     5.00
# Kilometers_Driven    39000.00
# Mileage                  5.93
# Engine_CC              771.00
# Power_bhp               60.03
# Seats                    0.00
# Price_Lakh               6.45
# dtype: float64

# %% [markdown]
# ### Removing outliers using IQR score

# %%
car = car[~((car < (Q1 - 1.5 * IQR)) |(car > (Q3 + 1.5 * IQR))).any(axis=1)]
car.shape
# Out:
# (4283, 11)

# %%
car.head()
# Out:
#    Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  \
# 0    10              72000       CNG       Manual      First    26.60
# 1     5              41000    Diesel       Manual      First    19.67
# 2     9              46000    Petrol       Manual      First    18.20
# 4     7              40670    Diesel    Automatic     Second    15.20
# 5     8              75000       LPG       Manual      First    21.10
#
#    Engine_CC  Power_bhp  Seats  Price_Lakh Manufacturer
# 0      998.0      58.16    5.0        1.75       Maruti
# 1     1582.0     126.20    5.0       12.50      Hyundai
# 2     1199.0      88.70    5.0        4.50        Honda
# 4     1968.0     140.80    5.0       17.74         Audi
# 5      814.0      55.20    5.0        2.35      Hyundai
