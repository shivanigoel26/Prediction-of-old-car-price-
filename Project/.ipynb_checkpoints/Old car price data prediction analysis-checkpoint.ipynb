# %% [markdown]
# # Data importing

# %%
# import package
import pandas as pd
import numpy as np
import pandas_profiling as pp
import matplotlib.pyplot as plt
# %matplotlib inline

#Reading CSV file
car_data = pd.read_csv('car.csv',index_col=0)

# data understanding
car_data.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price
# 0        NaN   1.75
# 1        NaN  12.50
# ...

# %%
#changing name of columns
car_data.columns = ['Name','Location','Year','Kilometers_Driven','Fuel_Type','Transmission','Owner_Type','Mileage',
                    'Engine_CC','Power_bhp','Seats','New_Price_Lakh','Price_Lakh']

# %% [markdown]
# # Data Analysis

# %%
# top 5 rows data
car_data.head(5)
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage Engine_CC  Power_bhp  Seats  \
# 0       CNG       Manual      First  26.6 km/kg    998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl   1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl   1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl   1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl   1968 CC  140.8 bhp    5.0
#
#   New_Price_Lakh  Price_Lakh
# 0            NaN        1.75
# ...

# %%
#bottom 5 rows data
car_data.tail(5)
# Out:
#                           Name   Location  Year  Kilometers_Driven Fuel_Type  \
# 6014          Maruti Swift VDI      Delhi  2014              27365    Diesel
# 6015  Hyundai Xcent 1.1 CRDi S     Jaipur  2015             100000    Diesel
# 6016     Mahindra Xylo D4 BSIV     Jaipur  2012              55000    Diesel
# 6017        Maruti Wagon R VXI    Kolkata  2013              46000    Petrol
# 6018     Chevrolet Beat Diesel  Hyderabad  2011              47000    Diesel
#
#      Transmission Owner_Type     Mileage Engine_CC Power_bhp  Seats  \
# 6014       Manual      First   28.4 kmpl   1248 CC    74 bhp    5.0
# 6015       Manual      First   24.4 kmpl   1120 CC    71 bhp    5.0
# 6016       Manual     Second   14.0 kmpl   2498 CC   112 bhp    8.0
# 6017       Manual      First   18.9 kmpl    998 CC  67.1 bhp    5.0
# 6018       Manual      First  25.44 kmpl    936 CC  57.6 bhp    5.0
#
#      New_Price_Lakh  Price_Lakh
# 6014      7.88 Lakh        4.75
# ...

# %%
# shape of our dataset
car_data.shape
# Out:
# (6019, 13)

# %% [markdown]
# ### There are total 6019 rows and 14 columns

# %%
#columns of data set
car_data.columns
# Out:
# Index(['Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine_CC', 'Power_bhp',
#        'Seats', 'New_Price_Lakh', 'Price_Lakh'],
#       dtype='object')

# %%
# information of data set
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6019 entries, 0 to 6018
# Data columns (total 13 columns):
# Name                 6019 non-null object
# Location             6019 non-null object
# Year                 6019 non-null int64
# Kilometers_Driven    6019 non-null int64
# Fuel_Type            6019 non-null object
# Transmission         6019 non-null object
# Owner_Type           6019 non-null object
# Mileage              6017 non-null object
# Engine_CC            5983 non-null object
# Power_bhp            5983 non-null object
# Seats                5977 non-null float64
# New_Price_Lakh       824 non-null object
# Price_Lakh           6019 non-null float64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 658.3+ KB

# %%
#size of dataset
car_data.size
# Out:
# 78247

# %%
#check datatype of each attributes
car_data.dtypes
# Out:
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage               object
# Engine_CC             object
# Power_bhp             object
# Seats                float64
# New_Price_Lakh        object
# Price_Lakh           float64
# dtype: object

# %%
# total number of each data types in data set  
car_data.get_dtype_counts()
# Out:
# float64    2
# int64      2
# object     9
# dtype: int64

# %%
# number of entities of each columns
car_data.count()
# Out:
# Name                 6019
# Location             6019
# Year                 6019
# Kilometers_Driven    6019
# Fuel_Type            6019
# Transmission         6019
# Owner_Type           6019
# Mileage              6017
# Engine_CC            5983
# Power_bhp            5983
# Seats                5977
# New_Price_Lakh        824
# Price_Lakh           6019
# dtype: int64

# %% [markdown]
# # Profile Report

# %%
# profile report of data set
pp.ProfileReport(car_data)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %% [markdown]
# # Filtering missing data

# %%
# check the NaN values
car_data.isnull()
# Out:
#        Name  Location   Year  Kilometers_Driven  Fuel_Type  Transmission  \
# 0     False     False  False              False      False         False
# 1     False     False  False              False      False         False
# 2     False     False  False              False      False         False
# 3     False     False  False              False      False         False
# 4     False     False  False              False      False         False
# 5     False     False  False              False      False         False
# 6     False     False  False              False      False         False
# 7     False     False  False              False      False         False
# 8     False     False  False              False      False         False
# 9     False     False  False              False      False         False
# 10    False     False  False              False      False         False
# 11    False     False  False              False      False         False
# ...

# %%
# sum of null values of each column
car_data.isnull().sum()
# Out:
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine_CC              36
# Power_bhp              36
# Seats                  42
# New_Price_Lakh       5195
# Price_Lakh              0
# dtype: int64

# %%
#dropping duplicate values
car_data.drop_duplicates()
# Out:
#                                                   Name    Location  Year  \
# 0                               Maruti Wagon R LXI CNG      Mumbai  2010
# 1                     Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2                                         Honda Jazz V     Chennai  2011
# 3                                    Maruti Ertiga VDI     Chennai  2012
# 4                      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 5                      Hyundai EON LPG Era Plus Option   Hyderabad  2012
# 6                               Nissan Micra Diesel XV      Jaipur  2013
# 7                    Toyota Innova Crysta 2.8 GX AT 8S      Mumbai  2016
# 8                  Volkswagen Vento Diesel Comfortline        Pune  2013
# 9                       Tata Indica Vista Quadrajet LS     Chennai  2012
# 10                                    Maruti Ciaz Zeta       Kochi  2018
# 11                         Honda City 1.5 V AT Sunroof     Kolkata  2012
# ...

# %% [markdown]
# # Transforming data usnig function

# %% [markdown]
# ## New Price

# %%
# converting data type of New_Price in str format 
convert_dict = {'New_Price_Lakh': str }

# %%
car_data = car_data.astype(convert_dict)

# %%
# function to change crore into lakh
def crore(x):
    l = x.split(' ')
    if "Cr" in x:
        return (str(float(l[0]) * 100) +" "+ "Lakh")
    if "Lakh" in x:
        return (str(float(l[0])) +" "+ "Lakh")
    else:
        return (str(float(l[0])))

# %%
# Applying New_Price(in Lakh) column values in crore()
car_data['New_Price_Lakh'] = car_data['New_Price_Lakh'].apply(crore)

# %%
# removing unit "Lakh" from column to analyse data
def clean_currency(x):
    if isinstance(x, str):
        return(x.replace('Lakh', '').replace(',', ''))
    return(x)

# %%
# updating New_Price(in Lakh) column values in data set
car_data['New_Price_Lakh'] = car_data['New_Price_Lakh'].apply(clean_currency).astype('float')

# %% [markdown]
# ## Engine

# %%
# removing unit "CC" from Engine column to analyse data
def clean_CC(y):
    if isinstance(y, str):
        return(y.replace('CC', '').replace(',', ''))
    return(y)

# %%
# applying clean_CC() to values of engine column
car_data['Engine_CC'] = car_data['Engine_CC'].apply(clean_CC).astype('float')

# %% [markdown]
# ## Power

# %%
# removing unit "bnp" from Power column to analyse data
def clean_bhp(z):
    if isinstance(z, str):
        return(z.replace('bhp', '').replace(',', ''))
    return(z)

# %%
# applying clean_bhp() to values of engine column
car_data['Power_bhp'] = car_data['Power_bhp'].apply(clean_bhp)

# %% [markdown]
# ## Mileage

# %%
# Transforming data of mileage fuction
convert_dict1 = {'Mileage': str }

# %%
car_data = car_data.astype(convert_dict1)

# %%
# function to chnage km/kg into kmpl
def kml(k):
    l = k.split(' ')
    if "km/kg" in k:
        return (str(float(l[0])) +" "+ "kmpl")
    if "kmpl" in k:
        return (str(float(l[0])) +" "+ "kmpl")
    else:
        return (str(float(l[0])))

# %%
# Applying Mileage column values in kml()
car_data['Mileage'] = car_data['Mileage'].apply(kml)

# %%
# removing units from  Mileage column to analyse data
def clean_unit(k1):
    if isinstance(k1, str):
        return(k1.replace('kmpl', '').replace(',', ''))
    return(k1)

# %%
# updating Mileage column values in data set
car_data['Mileage'] = car_data['Mileage'].apply(clean_unit)

# %%
#checking tha datatypes
car_data.dtypes
# Out:
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage               object
# Engine_CC            float64
# Power_bhp             object
# Seats                float64
# New_Price_Lakh       float64
# Price_Lakh           float64
# dtype: object

# %% [markdown]
# # Type conversion

# %%
#type conversion of Power(in bhp) from object type to float data type
car_data['Power_bhp'] = pd.to_numeric(car_data['Power_bhp'],errors='coerce')

# %%
car_data.Power_bhp.isna().sum()
# Out:
# 143

# %%
# type conversion of Mileage from object type to float
car_data['Mileage'] = pd.to_numeric(car_data['Mileage'],errors='coerce')

# %%
car_data.Mileage.isna().sum()
# Out:
# 2

# %%
car_data.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type  Mileage  Engine_CC  Power_bhp  Seats  \
# 0       CNG       Manual      First    26.60      998.0      58.16    5.0
# 1    Diesel       Manual      First    19.67     1582.0     126.20    5.0
# 2    Petrol       Manual      First    18.20     1199.0      88.70    5.0
# 3    Diesel       Manual      First    20.77     1248.0      88.76    7.0
# 4    Diesel    Automatic     Second    15.20     1968.0     140.80    5.0
#
#    New_Price_Lakh  Price_Lakh
# 0             NaN        1.75
# ...

# %%
# final data types of attributes of data set
car_data.dtypes
# Out:
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage              float64
# Engine_CC            float64
# Power_bhp            float64
# Seats                float64
# New_Price_Lakh       float64
# Price_Lakh           float64
# dtype: object

# %%
# Check the NaN values of attributes
car_data.isna().sum()
# Out:
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine_CC              36
# Power_bhp             143
# Seats                  42
# New_Price_Lakh       5195
# Price_Lakh              0
# dtype: int64

# %% [markdown]
# # Data cleaning

# %% [markdown]
# ## Mileage

# %%
car_data.Mileage.replace(0,np.nan)
# Out:
# 0       26.60
# 1       19.67
# 2       18.20
# 3       20.77
# 4       15.20
# 5       21.10
# 6       23.08
# 7       11.36
# 8       20.54
# 9       22.30
# 10      21.56
# 11      16.80
# 12      25.20
# 13      12.70
# 14        NaN
# 15      13.50
# 16      25.80
# 17      28.40
# 18      20.45
# 19      14.84
# 20      22.69
# 21      23.65
# 22      13.53
# 23      18.50
# 24      14.40
# 25      16.80
# 26      23.08
# 27      20.92
# 28      17.50
# 29      12.80
#         ...
# 5989    18.25
# 5990    13.93
# 5991    22.90
# 5992    13.70
# 5993    16.30
# 5994    17.00
# 5995    19.87
# 5996    16.36
# 5997    26.20
# 5998    17.24
# 5999    17.57
# 6000    18.50
# 6001    17.68
# 6002    16.09
# 6003    23.10
# 6004    15.30
# 6005    24.30
# 6006     8.70
# 6007    19.30
# 6008    17.85
# 6009    19.16
# 6010    18.50
# 6011      NaN
# 6012    12.80
# 6013    25.80
# 6014    28.40
# 6015    24.40
# 6016    14.00
# 6017    18.90
# 6018    25.44
# ...

# %%
car_data.Mileage.fillna(car_data.Engine_CC.median(),inplace=True)

# %%
car_data.Mileage.isna().sum()
# Out:
# 0

# %% [markdown]
# ## Engine

# %%
car_data.Engine_CC.replace(0,np.nan)
# Out:
# 0        998.0
# 1       1582.0
# 2       1199.0
# 3       1248.0
# 4       1968.0
# 5        814.0
# 6       1461.0
# 7       2755.0
# 8       1598.0
# 9       1248.0
# 10      1462.0
# 11      1497.0
# 12      1248.0
# 13      2179.0
# 14      2179.0
# 15      2477.0
# 16      1498.0
# 17      1248.0
# 18      1461.0
# 19      2143.0
# 20      1995.0
# 21      1248.0
# 22      1984.0
# 23      1197.0
# 24      1598.0
# 25      1497.0
# 26      1461.0
# 27       998.0
# 28      1199.0
# 29      2494.0
#          ...
# 5989    1968.0
# 5990    2179.0
# 5991    1248.0
# 5992    1798.0
# 5993    1797.0
# 5994    1497.0
# 5995    1461.0
# 5996    2179.0
# 5997     998.0
# 5998    1198.0
# 5999    1193.0
# 6000    1197.0
# 6001    1968.0
# 6002    1598.0
# 6003     998.0
# 6004    1341.0
# 6005    1248.0
# 6006    2987.0
# 6007    1248.0
# 6008    2967.0
# 6009    2494.0
# 6010    1198.0
# 6011    3597.0
# 6012    2494.0
# 6013    1498.0
# 6014    1248.0
# 6015    1120.0
# ...

# %%
car_data.Engine_CC.fillna(car_data.Engine_CC.median(),inplace=True)

# %%
car_data.Engine_CC.isna().sum()
# Out:
# 0

# %% [markdown]
# ## Power

# %%
car_data.Power_bhp.replace(0,np.nan)
# Out:
# 0        58.16
# 1       126.20
# 2        88.70
# 3        88.76
# 4       140.80
# 5        55.20
# 6        63.10
# 7       171.50
# 8       103.60
# 9        74.00
# 10      103.25
# 11      116.30
# 12       74.00
# 13      187.70
# 14      115.00
# 15      175.56
# 16       98.60
# 17       74.00
# 18       83.80
# 19      167.62
# 20      190.00
# 21       88.50
# 22      177.01
# 23       80.00
# 24      103.60
# 25      116.30
# 26       63.10
# 27       67.10
# 28       88.70
# 29      102.00
#          ...
# 5989    187.74
# 5990    138.00
# 5991     74.00
# 5992    157.75
# 5993    147.50
# 5994    118.00
# 5995     83.80
# 5996    187.70
# 5997     58.20
# 5998     73.90
# 5999     88.70
# 6000     82.85
# 6001    174.33
# 6002    103.50
# 6003     67.04
# 6004     83.00
# 6005     88.50
# 6006    224.34
# 6007     73.90
# 6008    300.00
# 6009    158.20
# 6010     86.80
# 6011    262.60
# 6012    102.00
# 6013     98.60
# 6014     74.00
# 6015     71.00
# ...

# %%
car_data.Power_bhp.fillna(car_data.Power_bhp.median(),inplace=True)

# %%
car_data.Power_bhp.isna().sum()
# Out:
# 0

# %% [markdown]
# ## Seats

# %%
car_data.Seats.replace(0,np.nan)
# Out:
# 0       5.0
# 1       5.0
# 2       5.0
# 3       7.0
# 4       5.0
# 5       5.0
# 6       5.0
# 7       8.0
# 8       5.0
# 9       5.0
# 10      5.0
# 11      5.0
# 12      5.0
# 13      5.0
# 14      5.0
# 15      7.0
# 16      5.0
# 17      5.0
# 18      5.0
# 19      5.0
# 20      5.0
# 21      5.0
# 22      5.0
# 23      5.0
# 24      5.0
# 25      5.0
# 26      5.0
# 27      5.0
# 28      5.0
# 29      7.0
#        ...
# 5989    5.0
# 5990    7.0
# 5991    5.0
# 5992    5.0
# 5993    5.0
# 5994    5.0
# 5995    5.0
# 5996    5.0
# 5997    5.0
# 5998    5.0
# 5999    5.0
# 6000    5.0
# 6001    5.0
# 6002    5.0
# 6003    5.0
# 6004    5.0
# 6005    5.0
# 6006    5.0
# 6007    5.0
# 6008    4.0
# 6009    5.0
# 6010    5.0
# 6011    5.0
# 6012    7.0
# 6013    5.0
# 6014    5.0
# 6015    5.0
# 6016    8.0
# 6017    5.0
# 6018    5.0
# Name: Seats, Length: 6019, dtype: float64

# %%
car_data.Seats.fillna(car_data.Seats.median(),inplace=True)

# %%
car_data.Seats.isna().sum()
# Out:
# 0

# %%
#Final data after cleaning
car_data.isna().sum()
# Out:
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 0
# Engine_CC               0
# Power_bhp               0
# Seats                   0
# New_Price_Lakh       5195
# Price_Lakh              0
# dtype: int64

# %%
#Storing the cleaned dataset in car_data file
car_data.to_csv('car_data.csv')

# %%
car_data.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type  Mileage  Engine_CC  Power_bhp  Seats  \
# 0       CNG       Manual      First    26.60      998.0      58.16    5.0
# 1    Diesel       Manual      First    19.67     1582.0     126.20    5.0
# 2    Petrol       Manual      First    18.20     1199.0      88.70    5.0
# 3    Diesel       Manual      First    20.77     1248.0      88.76    7.0
# 4    Diesel    Automatic     Second    15.20     1968.0     140.80    5.0
#
#    New_Price_Lakh  Price_Lakh
# 0             NaN        1.75
# ...

# %% [markdown]
# # DATA VISUALIZATION

# %% [markdown]
# ## Name

# %%
car_data['Name'].value_counts().plot(kind='barh')

# %% [markdown]
# ## Location

# %%
car_data['Location'].value_counts().plot(kind='pie')
car_data['Location'].value_counts()

# %% [markdown]
# ## Year

# %%
car_data['Year'].value_counts().plot(kind='bar')
car_data['Year'].value_counts()

# %% [markdown]
# ## Kilometers_Driven

# %%
car_data['Kilometers_Driven'].plot.hist(bins=100)

# %%
# plot graph using log as axis
fig,ax = plt.subplots()
ax.set_yscale('log')
car_data = car_data[car_data['Kilometers_Driven']< 1000000]
car_data['Kilometers_Driven'].plot.hist(bins=200)
len(car_data)

# %% [markdown]
# ## Fuel type

# %%
car_data['Fuel_Type'].value_counts().plot(kind='bar')
car_data['Fuel_Type'].value_counts()

# %% [markdown]
# ## Transmission

# %%
car_data['Transmission'].value_counts().plot(kind='pie')
car_data['Transmission'].value_counts()

# %% [markdown]
# ## Owner Type

# %%
car_data['Owner_Type'].value_counts().plot(kind='pie')
car_data['Owner_Type'].value_counts()

# %% [markdown]
# ## Mileage

# %%
car_data['Mileage'].value_counts().plot(kind='pie')

# %% [markdown]
# ## Engine

# %%
car_data['Engine_CC'].plot.hist(bins=200)
print("max: ", car_data['Engine_CC'].max())
print("min: ", car_data['Engine_CC'].min())
print("median: ", car_data['Engine_CC'].median())
print("mean: ", car_data['Engine_CC'].mean())
print("mode: ", car_data['Engine_CC'].mode())

# %% [markdown]
# ## Power

# %%
car_data['Power_bhp'].plot.hist(bins=100)
print("max: ", car_data['Power_bhp'].max())
print("min: ", car_data['Power_bhp'].min())
print("mean: ", car_data['Power_bhp'].mean())
print("median: ", car_data['Power_bhp'].median())
print("mode: ", car_data['Power_bhp'].mode())

# %% [markdown]
# ## Seats

# %%
car_data['Seats'].value_counts().plot(kind='bar')
car_data['Seats'].value_counts()
print("max: ", car_data['Seats'].max())
print("min: ", car_data['Seats'].min())
print("median: ", car_data['Seats'].median())
print("mean: ", car_data['Seats'].mean())
print("mode: ", car_data['Seats'].mode())

# %% [markdown]
# ## New_Price

# %%
car_data['New_Price_Lakh'].plot.hist(bins=200)

# %% [markdown]
# ## Price

# %%
car_data['Price_Lakh'].plot.hist(bins=200)
print("max: ", car_data['Price_Lakh'].max())
print("min: ", car_data['Price_Lakh'].min())
print("median: ", car_data['Price_Lakh'].median())
print("mean: ", car_data['Price_Lakh'].mean())
print("mode: ", car_data['Price_Lakh'].mode())

# %%
car_data.plot.scatter(x='Price_Lakh',
                      y='Engine_CC',
                      c='red')

# %%
car_data.plot.scatter(x='Price_Lakh',
                      y='Mileage',
                      c='blue')

# %%
car_data.plot.scatter(x='Power_bhp',
                      y='Price_Lakh',
                      c='red')

# %%
car_data.plot.scatter(x='Year',
                      y='Price_Lakh',
                      c='red')

# %% [markdown]
# # Cleaned data

# %%
car_data.head()

# %%
car_data.describe()

# %%
import seaborn as sns
sns.countplot(car_data['New_Price_Lakh'])

# %% [markdown]
# # Distribution graph

# %%
sns.set_style('darkgrid')
sns.distplot(car_data['Price_Lakh'],color='red')

# %%
plt.hist(car_data['Price_Lakh'])

# %%
mean=[0,0]
cov=[[0.2,0],[0,3]]

# %%
x_axis,y_axis=np.random.multivariate_normal(mean,cov).T
x_axis

# %%
y_axis

# %%
sns.kdeplot(x_axis,shade=True,color='yellow')

# %% [markdown]
# # split plot

# %%
sns.stripplot(x=car_data['Mileage'],color='red')

# %%
sns.stripplot(x=car_data['Price_Lakh'],color='purple')

# %%
sns.stripplot(x='Price_Lakh',y='Engine_CC',hue='Transmission',data=car_data)

# %%
sns.stripplot(x='Price_Lakh',y='Engine_CC',hue='Transmission',data=car_data,jitter=20)

# %% [markdown]
# # Box plot

# %%
sns.boxplot(x=car_data['Seats'])

# %%
sns.boxplot(x='Fuel_Type',y='Price_Lakh',data=car_data)

# %%
car_data.describe()

# %% [markdown]
# # Histogram

# %%
car_data.hist(figsize=(12,12))

# %% [markdown]
# # Categorical data

# %%
import seaborn as sns

# %%
sns.countplot(car_data['Fuel_Type'])
plt.title("Fuel Type")
plt.xlabel('fuel type')
plt.ylabel('Count')
plt.show()

# %%
survive = sns.countplot(x = 'Fuel_Type', hue = 'Transmission', palette = 'Set3', data = car_data)
survive.set(title = 'Fuel Type against Transmission', xlabel = 'Fuel type',ylabel="Mileage")
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# # Univariate analysis

# %%
sns.distplot(car_data['Price'])

# %%
plt1 = sns.countplot(car_data['Power'])
plt1.set(xlabel = 'Symbol', ylabel= 'Power')
plt.show()
plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize = (15,5))
plt1 = sns.countplot(car_data['Name'], order=pd.value_counts(car_data['Name']).index)
plt1.set(xlabel = 'Brand', ylabel= 'Count')
plt.show()

# %%
#univariate analysis
for i in car_data.describe().columns:
    sns.distplot(car_data[i])
    plt.show()

# %% [markdown]
# # Correlation Matrix

# %%
import seaborn as sns
plt.figure(figsize=(12,6))
sns.heatmap(car_data.corr(),annot=True,cmap='YlGnBu')

# %% [markdown]
# # Bivariate analysis

# %%
#bivariate analysis
for i, col in enumerate (car_data.columns):
    plt.figure(i)
    sns.scatterplot(x=car_data[col],y=car_data['Price'])

# %%
#Bivariate analysis
plt.figure(figsize=(12,8))

plt.title('Mileage vs Price')
sns.scatterplot(x=car_data['Mileage'],y=car_data['Price'])
plt.xlabel('Mileage')
plt.ylabel('Price')

plt.show()
plt.tight_layout()

# %%
#bivariate analysis
sns.pairplot(car_data)

# %% [markdown]
# # identify and removing outliers

# %%
#identify ouliers
for i in car_data.describe().columns:
    sns.boxplot(car_data[i])
    plt.show()

# %%
#removing outliers
def remove_outliers(car_data):
    outliers={}
    for col in car_data.columns:
        if str(car_data[col].dtype)!='object':
            car_data=car_data[np.abs(car_data[col]-car_data[col].mean())<(3*car_data[col].std())]
            olrs=df[~(np.abs(car_data[col]-car_data[col].mean())<(3*car_data[col].std()))]
            outliers=pd.DataFrame(olrs)
    return car_data,outliers
plt.show()
